# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 1, 3) # 3 points between 0 and 1
y = np.array([1, 0, 1])

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('1')
plt.show()

# %%
omega = np.polyfit(x, y, 2) # 1元2次方程式
omega
# Out:
# array([ 4., -4.,  1.])

# %%
f = np.poly1d(omega)

plt.xlabel('x')
plt.ylabel('y')
plt.title('2')
plt.grid()
plt.scatter(x, y, marker='x', c='red')

plt.plot(x, f(x), color='green')

plt.show()
